# %%
# ============ #
# 1. LIBRERÍAS #
# ============ #

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.model_selection import train_test_split, cross_validate
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.metrics import mean_absolute_percentage_error

# %%
# =================== #
# 2. LECTURA DE RUTAS #
# =================== #

mainpath = os.path.join(os.getcwd(), "..", "..", "data", "raw")
filename = "job_salary_prediction_dataset.csv"
fullpath = os.path.join(mainpath, filename)

# %%
# ================= #
# 3. CARGA DE DATOS #
# ================= #

df = pd.read_csv(fullpath, sep=",")
pd.set_option('display.max_columns', None)

# %%
# ============================== #
# 4. IDENTIFICACIÓN DE VARIABLES #
# ============================== #

def variables(df = df):
    float_cols = df.select_dtypes(include='float64').columns.tolist()
    int_cols = df.select_dtypes(include='int64').columns.tolist()
    cat_cols = df.select_dtypes(include=['object', 'category']).columns.tolist()
    target = 'salary'
    features = [col for col in float_cols + int_cols if col != target]
    return features, target, cat_cols

features, target, cat_cols = variables()
# Out:
# C:\Users\saria\AppData\Local\Temp\ipykernel_10280\2578039198.py:8: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   cat_cols = df.select_dtypes(include=['object', 'category']).columns.tolist()

# %%
# ================ #
# 5. PREPROCESADOR #
# ================ #

preprocessor = ColumnTransformer([
    ('cat', OneHotEncoder(drop='first', handle_unknown='ignore'), cat_cols),
    ('num', 'passthrough', features)
])

# %%
# =============================== #
# VISUALIZAR EL PRE-PROCESAMIENTO #
# =============================== #

preprocessor
# Out:
# ColumnTransformer(transformers=[('cat',
#                                  OneHotEncoder(drop='first',
#                                                handle_unknown='ignore'),
#                                  ['job_title', 'education_level', 'industry',
#                                   'company_size', 'location', 'remote_work']),
#                                 ('num', 'passthrough',
#                                  ['experience_years', 'skills_count',
#                                   'certifications'])])

# %%
# ========================= #
# 6. PARTICIÓN TRAIN / TEST #
# ========================= #

X = df[features + cat_cols]
y = df[target]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# %%
# =========== #
# 7. MODELO XGBOOST #
# =========== #

model = Pipeline(steps=[
    ('preprocessing', preprocessor),
    ('regressor', XGBRegressor(random_state=42))
])

model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
#                                                   ['job_title',
#                                                    'education_level',
#                                                    'industry', 'company_size',
#                                                    'location', 'remote_work']),
#                                                  ('num', 'passthrough',
#                                                   ['experience_years',
#                                                    'skills_count',
#                                                    'certifications'])])),
#                 ('regressor',
#                  XGBRegressor(base_score=None, booster=None, callbacks...
#                               feature_types=None, feature_weights=None,
#                               gamma=None, grow_policy=None,
#                               importance_type=None,
#                               interaction_constraints=None, learning_rate=None,
#                               max_bin=None, max_cat_threshold=None,
#                               max_cat_to_onehot=None, max_delta_step=None,
#                               max_depth=None, max_leaves=None,
#                               min_child_weight=None, missing=nan,
#                               monotone_constraints=None, multi_strategy=None,
#                               n_estimators=None, n_jobs=None,
#                               num_parallel_tree=None, ...))])

# %%
# ============== #
# 8. EVALUACIÓN  #
# ============== #

y_pred = model.predict(X_test)

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mape = mean_absolute_percentage_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("MAE:", mae)
print("RMSE:", rmse)
print("MAPE:", mape)
print("MAPE(%):", mape * 100)
print("R2:", r2)
# Out:
# MAE: 4660.2109375
# RMSE: 5904.574497794062
# MAPE: 0.03385743871331215
# MAPE(%): 3.385743871331215
# R2: 0.9749821424484253

# %%
# ======================================== #
# 8.1. DATAFRAME CON RESULTADOS Y ERRORES  #
# ======================================== #

X_test_df = pd.DataFrame(X_test).reset_index(drop=True)
y_test_df = pd.Series(y_test).reset_index(drop=True)
y_pred_df = pd.Series(y_pred)

df_resultados = X_test_df.copy()
df_resultados["y_real"] = y_test_df
df_resultados["y_pred"] = y_pred_df
df_resultados["error"] = df_resultados["y_real"] - df_resultados["y_pred"]
df_resultados["abs_error"] = df_resultados["error"].abs()

df_resultados.sample(20)
# Out:
#        experience_years  skills_count  certifications  \
# 4108                  2            13               2
# 72654                14             7               4
# 38144                12             4               1
# 34520                 1            10               1
# 11089                 4             4               1
# 15310                12            10               0
# 49785                13             9               5
# 10610                14            16               0
# 42119                18             7               3
# 14281                14            19               4
# 58118                19            16               5
# 41808                 0            11               5
# 31275                 1             5               4
# 51714                18             4               3
# 40084                 6             5               2
# 6696                 19             2               4
# 73628                10            13               1
# 35933                16            19               0
# 15419                15             6               3
# 62968                17             8               4
#
#                        job_title education_level       industry company_size  \
# 4108          Frontend Developer     High School        Telecom        Small
# 72654                AI Engineer        Bachelor  Manufacturing        Large
# 38144  Machine Learning Engineer        Bachelor     Government   Enterprise
# 34520          Backend Developer     High School          Media        Small
# 11089      Cybersecurity Analyst             PhD     Government      Startup
# 15310             Cloud Engineer     High School     Healthcare        Large
# 49785         Frontend Developer        Bachelor        Telecom        Large
# 10610             Data Scientist             PhD     Healthcare   Enterprise
# 42119  Machine Learning Engineer         Diploma  Manufacturing      Startup
# 14281               Data Analyst          Master  Manufacturing        Small
# 58118            Product Manager             PhD        Finance   Enterprise
# 41808             Cloud Engineer          Master     Consulting        Small
# 31275      Cybersecurity Analyst     High School        Telecom       Medium
# 51714           Business Analyst             PhD        Finance        Small
# 40084      Cybersecurity Analyst     High School     Technology        Large
# 6696                Data Analyst        Bachelor          Media      Startup
# 73628            Product Manager     High School     Technology      Startup
# 35933      Cybersecurity Analyst             PhD     Government        Small
# 15419      Cybersecurity Analyst         Diploma     Technology        Large
# 62968      Cybersecurity Analyst             PhD     Technology      Startup
#
#           location remote_work  y_real         y_pred         error  \
# 4108           USA      Hybrid  110263  107921.007812   2341.992188
# 72654       Sweden      Hybrid  191075  180816.500000  10258.500000
# 38144       Canada      Hybrid  202307  212599.171875 -10292.171875
# 34520          USA      Hybrid  107876  111126.859375  -3250.859375
# 11089  Netherlands      Hybrid  124109  118542.367188   5566.632812
# 15310       Sweden      Hybrid  136970  140884.890625  -3914.890625
# 49785       Remote      Hybrid  133216  141957.468750  -8741.468750
# 10610       Remote         Yes  200198  201410.921875  -1212.921875
# 42119      Germany          No  160865  164763.265625  -3898.265625
# 14281       Canada         Yes  161042  161896.203125   -854.203125
# 58118           UK         Yes  274646  266485.781250   8160.218750
# 41808       Sweden      Hybrid  118644  120220.320312  -1576.320312
# 31275    Australia          No   88934   97253.890625  -8319.890625
# 51714          USA          No  180239  180423.828125   -184.828125
# 40084       Remote         Yes  121711  124961.312500  -3250.312500
# 6696        Canada          No  133402  132125.453125   1276.546875
# 73628    Singapore         Yes  120552  125375.539062  -4823.539062
# 35933  Netherlands          No  163210  166176.546875  -2966.546875
# 15419       Remote      Hybrid  148758  154726.406250  -5968.406250
# 62968           UK          No  185800  179920.328125   5879.671875
#
#           abs_error
# 4108    2341.992188
# 72654  10258.500000
# 38144  10292.171875
# 34520   3250.859375
# 11089   5566.632812
# 15310   3914.890625
# 49785   8741.468750
# 10610   1212.921875
# 42119   3898.265625
# 14281    854.203125
# 58118   8160.218750
# 41808   1576.320312
# 31275   8319.890625
# 51714    184.828125
# 40084   3250.312500
# 6696    1276.546875
# 73628   4823.539062
# 35933   2966.546875
# 15419   5968.406250
# 62968   5879.671875

# %%
# ====================== #
# 8.2. REAL VS PREDICHO  #
# ====================== #

plt.scatter(df_resultados["y_real"], df_resultados["y_pred"])
plt.xlabel("Valores reales")
plt.ylabel("Predicciones")
plt.title("Real vs Predicho - XGBOOST")
plt.plot(
    [df_resultados["y_real"].min(), df_resultados["y_real"].max()],
    [df_resultados["y_real"].min(), df_resultados["y_real"].max()]
)
plt.show()

# %%
# ============================= #
# 8.3. DISTRIBUCIÓN DE ERRORES  #
# ============================= #

plt.hist(df_resultados["error"], bins=30)
plt.title("Distribución del error - XGBOOST")
plt.xlabel("Error")
plt.ylabel("Frecuencia")
plt.show()

# %%
from sklearn.model_selection import cross_validate
import numpy as np

scoring = {'mae': 'neg_mean_absolute_error', 'rmse': 'neg_root_mean_squared_error', 'r2': 'r2'}
# Verificamos que se llame 'model'
cv_results = cross_validate(model, X_train, y_train, cv=10, scoring=scoring)

print(f"--- RESULTADOS MODELO {model.steps[-1][0].upper()} ---")
print(f"MAE  Promedio: {-cv_results['test_mae'].mean():.2f}")
print(f"RMSE Promedio: {-cv_results['test_rmse'].mean():.2f}")
print(f"R²   Promedio: {cv_results['test_r2'].mean():.4f} (Std: {cv_results['test_r2'].std():.4f})")
# Out:
# --- RESULTADOS MODELO REGRESSOR ---
# MAE  Promedio: 4683.60
# RMSE Promedio: 5938.74
# R²   Promedio: 0.9748 (Std: 0.0005)
